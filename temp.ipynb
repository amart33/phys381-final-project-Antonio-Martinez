# %%
print("Starting PHYS 381 Final Project")
# Out:
# Starting PHYS 381 Final Project

# %%
import PIL
from PIL import Image

img = Image.open('my plot.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1920>
